# %%
# %pip install --upgrade --quiet datasets pandas pymongo sentence_transformers transformers accelerate pinecone-client

# %% [markdown]
# # Data loading

# %%
from datasets import load_dataset
import pandas as pd

dataset=load_dataset("MongoDB/embedded_movies")
data=pd.DataFrame(dataset['train'])

# %%
data.head(2)
# Out:
#                               directors                  title  \
# 0  [Louis J. Gasnier, Donald MacKenzie]  The Perils of Pauline
# 1       [Alfred J. Goulding, Hal Roach]     From Hand to Mouth
#
#                                          imdb  \
# 0   {'id': 4465, 'rating': 7.6, 'votes': 744}
# 1  {'id': 10146, 'rating': 7.0, 'votes': 639}
#
#                                       plot_embedding  \
# 0  [0.00072939653, -0.026834568, 0.013515796, -0....
# 1  [-0.022837115, -0.022941574, 0.014937485, -0.0...
#
#                                               awards rated countries   type  \
# 0    {'nominations': 0, 'text': '1 win.', 'wins': 1}  None     [USA]  movie
# 1  {'nominations': 1, 'text': '1 nomination.', 'w...  TV-G     [USA]  movie
#
#                                              writers  metacritic  languages  \
# 0  [Charles W. Goddard (screenplay), Basil Dickey...         NaN  [English]
# 1                             [H.M. Walker (titles)]         NaN  [English]
#
# ...

# %%
data.isnull().sum()
# Out:
# directors              13
# title                   0
# imdb                    0
# plot_embedding         28
# awards                  0
# rated                 308
# countries               0
# type                    0
# writers                13
# metacritic            928
# languages               1
# fullplot               48
# genres                  0
# poster                 89
# cast                    1
# runtime                15
# plot                   27
# num_mflix_comments      0
# dtype: int64

# %%
# Drop the null valued fullplot
data=data.dropna(subset=["fullplot"])
data.head(2)
# Out:
#                               directors                  title  \
# 0  [Louis J. Gasnier, Donald MacKenzie]  The Perils of Pauline
# 1       [Alfred J. Goulding, Hal Roach]     From Hand to Mouth
#
#                                          imdb  \
# 0   {'id': 4465, 'rating': 7.6, 'votes': 744}
# 1  {'id': 10146, 'rating': 7.0, 'votes': 639}
#
#                                       plot_embedding  \
# 0  [0.00072939653, -0.026834568, 0.013515796, -0....
# 1  [-0.022837115, -0.022941574, 0.014937485, -0.0...
#
#                                               awards rated countries   type  \
# 0    {'nominations': 0, 'text': '1 win.', 'wins': 1}  None     [USA]  movie
# 1  {'nominations': 1, 'text': '1 nomination.', 'w...  TV-G     [USA]  movie
#
#                                              writers  metacritic  languages  \
# 0  [Charles W. Goddard (screenplay), Basil Dickey...         NaN  [English]
# 1                             [H.M. Walker (titles)]         NaN  [English]
#
# ...

# %%
# Drop the plot_embedding column
data=data.drop(columns=["plot_embedding"])

# %%
data=data.sample(80)

# %%
data.shape
# Out:
# (80, 17)

# %% [markdown]
# # MongoDB

# %%
import pymongo
from pymongo.mongo_client import MongoClient

uri = "mongodb+srv://sandeep:sandeep@cluster0.iis2lsd.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)

db=client["Mongo_pinecone"]
collection=db["mytestmongo_3"]
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
documents= data.to_dict("records")

# %%
collection.insert_many(documents)
# Out:
# InsertManyResult([ObjectId('663f560de6f47df7c349895f'), ObjectId('663f560de6f47df7c3498960'), ObjectId('663f560de6f47df7c3498961'), ObjectId('663f560de6f47df7c3498962'), ObjectId('663f560de6f47df7c3498963'), ObjectId('663f560de6f47df7c3498964'), ObjectId('663f560de6f47df7c3498965'), ObjectId('663f560de6f47df7c3498966'), ObjectId('663f560de6f47df7c3498967'), ObjectId('663f560de6f47df7c3498968'), ObjectId('663f560de6f47df7c3498969'), ObjectId('663f560de6f47df7c349896a'), ObjectId('663f560de6f47df7c349896b'), ObjectId('663f560de6f47df7c349896c'), ObjectId('663f560de6f47df7c349896d'), ObjectId('663f560de6f47df7c349896e'), ObjectId('663f560de6f47df7c349896f'), ObjectId('663f560de6f47df7c3498970'), ObjectId('663f560de6f47df7c3498971'), ObjectId('663f560de6f47df7c3498972'), ObjectId('663f560de6f47df7c3498973'), ObjectId('663f560de6f47df7c3498974'), ObjectId('663f560de6f47df7c3498975'), ObjectId('663f560de6f47df7c3498976'), ObjectId('663f560de6f47df7c3498977'), ObjectId('663f560de6f47df7c349
# ...

# %% [markdown]
# # Embedding

# %%
from sentence_transformers import SentenceTransformer
embedding_model = SentenceTransformer("thenlper/gte-large")

#ABout get-latge model: https://huggingface.co/thenlper/gte-large
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %% [markdown]
# # Pinecone

# %%
from pinecone import Pinecone
PINECONE_API_KEY="2ab4ebeb-323c-4e0"
pc = Pinecone(api_key=PINECONE_API_KEY)
index = pc.Index("mongomovie2")  #Index name

# %%
def get_results(query, similar_result=2):
  embedding= embedding_model.encode(query)
  embedding=embedding.tolist()

  result = index.query(
      vector = embedding,
      top_k = similar_result,
  )
  return result

# %%
query= "best horror movie to watch?"
result = get_results(query)

# %%
result
# Out:
# {'matches': [{'id': '663f560de6f47df7c3498977',
#               'score': 0.7801494,
#               'values': []},
#              {'id': '663f560de6f47df7c349897f',
#               'score': 0.769434273,
#               'values': []}],
#  'namespace': '',
#  'usage': {'read_units': 5}}

# %%
from bson.objectid import ObjectId

mylist=[]
for i in  range(len(result["matches"])):
  value=result["matches"][i]['id']
  mylist.append(collection.find_one({"_id": ObjectId(value)}))

# %%
mylist
# Out:
# [{'_id': ObjectId('663f560de6f47df7c3498977'),
#   'directors': ['Mark A.Z. Dippè'],
#   'title': 'Spawn',
#   'imdb': {'id': 120177, 'rating': 5.2, 'votes': 49909},
#   'awards': {'nominations': 5, 'text': '1 win & 5 nominations.', 'wins': 1},
#   'rated': 'R',
#   'countries': ['USA'],
#   'type': 'movie',
#   'writers': ['Todd McFarlane (comic book)',
#    'Alan B. McElroy (screen story)',
#    'Mark A.Z. Dippè (screen story)',
#    'Alan B. McElroy (screenplay)'],
#   'metacritic': 34.0,
#   'languages': ['English'],
#   'fullplot': "An assassin named Al Simmons is double-crossed and murdered by his evil boss Jason Wynn. Al makes a deal with the devil and returns to earth as Spawn to see his wife. He is ordered by the devil's minion, The Clown, to kill Wynn. Wynn has made a deal with the clown too and is suppose to destroy the world with a deadly virus that will help start Armageddon and allow Hell to attack Heaven. Spawn must choose between Good & Evil.",
# ...

# %%
combined_information = ""
for i in range(len(mylist)):
  fullplot=mylist[i]["fullplot"]
  title=mylist[i]["title"]
  combined_information += f"Title:{title}, fullplot: {fullplot}\n"

# %%
print(combined_information)
# Out:
# Title:Spawn, fullplot: An assassin named Al Simmons is double-crossed and murdered by his evil boss Jason Wynn. Al makes a deal with the devil and returns to earth as Spawn to see his wife. He is ordered by the devil's minion, The Clown, to kill Wynn. Wynn has made a deal with the clown too and is suppose to destroy the world with a deadly virus that will help start Armageddon and allow Hell to attack Heaven. Spawn must choose between Good & Evil.
# Title:Troma's War, fullplot: A small group of typical Tromaville citizens find themselves in the path of a terrorist army controlled by the power elite. The freedom of Tromaville and the world is at stake! Troma's War creates new kinds of heroes. A used car salesman, a handsome environmentalist, an obese junk-food gourmand, a seventy-year-old housewife, some sensational young women, a year old jingoistic baby and more sensational women all become deadly soldiers...

# %% [markdown]
# Using LLM to print the Answer

# %%
# %pip install --upgrade huggingface_hub

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
prompt = f"Query: {query}\nContinue to answer the query by using the fullplot only:\n{combined_information}."
print(prompt)
# Out:
# Query: best horror movie to watch?
# Continue to answer the query by using the fullplot only:
# Title:Spawn, fullplot: An assassin named Al Simmons is double-crossed and murdered by his evil boss Jason Wynn. Al makes a deal with the devil and returns to earth as Spawn to see his wife. He is ordered by the devil's minion, The Clown, to kill Wynn. Wynn has made a deal with the clown too and is suppose to destroy the world with a deadly virus that will help start Armageddon and allow Hell to attack Heaven. Spawn must choose between Good & Evil.
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("google/gemma-2b-it")
# CPU Enabled uncomment below 👇🏽
# model = AutoModelForCausalLM.from_pretrained("google/gemma-2b-it")
# GPU Enabled use below 👇🏽
model = AutoModelForCausalLM.from_pretrained("google/gemma-2b-it", device_map="auto")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Gemma's activation function should be approximate GeLU and not exact GeLU.
# Changing the activation function to `gelu_pytorch_tanh`.if you want to use the legacy `gelu`, edit the `model.config` to set `hidden_activation=gelu`   instead of `hidden_act`. See https://github.com/huggingface/transformers/pull/29402 for more details.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
# Moving tensors to GPU
input_ids = tokenizer(prompt, return_tensors="pt")

# %%
response = model.generate(**input_ids, max_new_tokens=500)

# %%
print(tokenizer.decode(response[0]))
# Out:
# <bos>Query: best horror movie to watch?
# Continue to answer the query by using the fullplot only:
# Title:Spawn, fullplot: An assassin named Al Simmons is double-crossed and murdered by his evil boss Jason Wynn. Al makes a deal with the devil and returns to earth as Spawn to see his wife. He is ordered by the devil's minion, The Clown, to kill Wynn. Wynn has made a deal with the clown too and is suppose to destroy the world with a deadly virus that will help start Armageddon and allow Hell to attack Heaven. Spawn must choose between Good & Evil.
# ...
